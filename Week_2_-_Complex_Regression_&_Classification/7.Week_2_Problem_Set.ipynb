# %% [markdown]
# # Week 2 - Problem Set
#
# Practice what you learnt today with these problems; I will share the answers on Monday before the next workshop.

# %%
# Run the dependencies before you begin
import numpy as np
import matplotlib.pyplot as plt
from utils_common import generate_data

plt.style.use('ggplot')

# %% [markdown]
# **1. Using MD syntax, create a table of the two regression algorithms we have covered so far with the following headings.**
#
#
# | Algorithm | Regression/Classification | Popular Uses |
# | --- | --- | --- |
# | Linear | Regression | Prediction based on previous trends in data |
# | Logistic | Classification | Binary data sorting - yes or no to a given value |

# %% [markdown]
# **2. In a markdown block, outline why more than 3 degrees of polynomial expression are not recommended in Machine Learning.**

# %% [markdown]
# More than 3 degrees of polynomial expression aren't recommended in Machine Learning due to the fact that more degrees typically take up more computing power, as well as making a prediction overfit for the data.

# %% [markdown]
# **3. Modify the code block below to label the two categories, apply a colour to each category, enable the legend, add a title "Logistic Data," and label the X & Y Axis with "Feature" and "Target."**
#
# | Category | Label |
# | --- | --- |
# | 0 | Australia |
# | 1 | New Zealand |

# %%
# Linear Regression For Classification
m = generate_data(20, 50, 0, 0, 300, 0.8)
n = generate_data(0, 30, 1, 1, 300, 0.8)
plt.scatter(m[0], m[1], c='r')
plt.scatter(n[0], n[1], c='b')
plt.title("Logistic Data")
plt.ylabel("Target")
plt.xlabel("Feature")
plt.show()

# %% [markdown]
# **4. In a markdown block, outline why Linear Regression is not a good machine learning model for classification.**

# %% [markdown]
# Linear regression isn't a good model for classification because the way it classifies data has a less certain prediction of how close data is to the target when classifying binary values. These values may be classified incorrectly due to them lying too close to the classification line in a linear regression model.

# %% [markdown]
# __5. In a markdown block, outline the machine learning Logistic Regression algorithm.__

# %% [markdown]
# Logistic regression is used for the classification of data into two groups based on existing data. The unique shape of the logistic regression function - sigmoid, is much better at handling boundary values than most other models.

# %% [markdown]
# **6. Using the [OOP Logistic Regression](4.OOP_Logistic_Regression.ipynb) as an example, design, fit and evaluate an [Iris classification OOP implementation](6.OOP_Iris_Logistic_Regression.ipynb).**

# %% [markdown]
# __7. After completing Logistic Regression for the Iris data set (Q6), justify why you selected the features you did for your model.__

# %% [markdown]
# I selected the features I did for my model because they were the features listed in the classification. I used logistic regression because this dataset deals with a binary selection, therefore logistic is more effective for the reasons stated above.
